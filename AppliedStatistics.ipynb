# %% [markdown]
# <a href="https://colab.research.google.com/github/srivakshay/pgpaiml/blob/PGPAIML/AppliedStatistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.A Refer above table and find the joint probability of the people who planned to purchase and actually placed an order

# %%
people_planned_purchase, total_people = 400, 2000
joint_probability = people_planned_purchase/total_people
print("Joint probability of the people who planned to purchase and actually placed an order.",joint_probability)
# Out:
# Joint probability of the people who planned to purchase and actually placed an order. 0.2

# %% [markdown]
# 1.B Refer to the above table and find the joint probability of the people who planned to purchase and actually placed an order, given that
# people planned to purchase.

# %%
people_planned_purchase, planned_to_purchase_yes_total = 400, 500

joint_probability = people_planned_purchase / planned_to_purchase_yes_total

print("joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase", joint_probability)
# Out:
# joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase 0.8

# %% [markdown]
# **2. An electrical manufacturing company conducts quality checks at specified periods on the products it manufactures. Historically, the failure rate for the manufactured item is 5%. Suppose a random sample of 10 manufactured items is selected. Answer the following questions**

# %% [markdown]
# 2.A Probability that none of the items are defective?

# %%
from scipy.stats import binom

n = 10  # sample size
p_defective = 0.05  # probability of an item being defective
k = 0  # number of defective items

# Calculate the probability
probability_none_defective = binom.pmf(k, n, p_defective)

print("Probability that none of the items are defective:", probability_none_defective)
# Out:
# Probability that none of the items are defective: 0.5987369392383789

# %% [markdown]
# 2.B Probability that exactly one of the items is defective

# %%
k = 1  # number of defective items

# Calculate the probability
probability_one_defective = binom.pmf(k, n, p_defective)

# Print the result
print("Probability that exactly one item is defective:", probability_one_defective)
# Out:
# Probability that exactly one item is defective: 0.3151247048623047

# %% [markdown]
# 2.C. Probability that two or fewer of the items are defective?

# %%
k = 2  # number of defective items

# Calculate the cumulative probability
probability_two_or_fewer_defective = binom.cdf(k, n, p_defective)

# Print the result
print("Probability that two or fewer items are defective:", probability_two_or_fewer_defective)
# Out:
# Probability that two or fewer items are defective: 0.9884964426207031

# %% [markdown]
# 2.D. Probability that three or more of the items are defective ?

# %%
k = 3  # number of defective items

# Calculate the complement probability
probability_three_or_more_defective = 1 - binom.cdf(k - 1, n, p_defective)

# Print the result
print("Probability that three or more items are defective:", probability_three_or_more_defective)
# Out:
# Probability that three or more items are defective: 0.01150355737929687

# %% [markdown]
# **3. A car salesman sells on an average 3 cars per week**

# %% [markdown]
# 3.A. What is Probability that in a given week he will sell some cars?

# %%
from scipy.stats import poisson


average_cars_sold = 3 # Average number of cars sold per week


probability_zero_cars = poisson.pmf(0, average_cars_sold) # Calculate the probability of selling zero cars


probability_some_cars = 1 - probability_zero_cars # Calculate the probability of selling some cars

print(f"Probability of selling some cars in a given week: {probability_some_cars}")
# Out:
# Probability of selling some cars in a given week: 0.950212931632136

# %% [markdown]
# 3.B. What is Probability that in a given week he will sell 2 or more but less than 5 cars?

# %%
probability_less_than_5 = poisson.cdf(4, average_cars_sold) #cumulative probability of selling less than 5 cars


probability_less_than_2 = poisson.cdf(1, average_cars_sold) # cumulative probability of selling less than 2 cars


probability_2_or_more_and_less_than_5 = probability_less_than_5 - probability_less_than_2 # probability of selling 2 or more but less than 5 cars

print(f"Probability of selling 2 or more but less than 5 cars in a given week: {probability_2_or_more_and_less_than_5}")
# Out:
# Probability of selling 2 or more but less than 5 cars in a given week: 0.6161149710523164

# %% [markdown]
# 3.C. Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold per week.

# %%
import matplotlib.pyplot as plt
import numpy as np

x_values = np.arange(0, 11)  # assuming a range from 0 to 10 cars sold


cumulative_probabilities = poisson.cdf(x_values, average_cars_sold) # Calculate cumulative probability for each x value

# Plot the cumulative probability function
plt.plot(x_values, cumulative_probabilities, marker='X')
plt.title('Poisson Distribution - Cumulative Probability of Cars Sold per Week')
plt.xlabel('Number of Cars Sold per Week')
plt.ylabel('Cumulative Probability')
plt.grid(True)
plt.show()

# %% [markdown]
# **4 Accuracy in understanding orders for a speech based bot at a restaurant is important for the Company X which has designed,
# marketed and launched the product for a contactless delivery due to the COVID-19 pandemic. Recognition accuracy that measures the
# percentage of orders that are taken correctly is 86.8%. Suppose that you place an order with the bot and two friends of yours
# independently place orders with the same bot. Answer the following questions**

# %% [markdown]
# 4.A. What is the probability that all three orders will be recognised correctly?

# %%
# fixed number of order
n=3

# probility of correct recognition
p_success=0.868

# array of quantities
k = np.arange(0,4)

binomial1 = binom.cdf(k,n,p_success)
print(f"Probability that all three orders will be recognized correctly (using binomial distribution): {1-binomial1[2]}")
# Out:
# Probability that all three orders will be recognized correctly (using binomial distribution): 0.653972032

# %% [markdown]
# 4.B. What is the probability that none of the three orders will be recognised correctly?

# %%
print(f"Probability that none of the three orders will be recognized correctly (using binomial distribution): {binomial1[0]}")
# Out:
# Probability that none of the three orders will be recognized correctly (using binomial distribution): 0.0022999680000000003

# %% [markdown]
# 4.C. What is the probability that at least two of the three orders will be recognised correctly?

# %%
# Probability of exactly two correct orders
binom_p=binom.pmf(k,n,p_success)

probability_two_correct_binom = binom_p[2]

# Probability of all three correct orders
probability_all_correct_binom = binom_p[3]

# Probability of at least two correct orders
probability_at_least_two_correct_binom = probability_two_correct_binom + probability_all_correct_binom

print(f"Probability that at least two of the three orders will be recognized correctly : {probability_at_least_two_correct_binom}")
# Out:
# Probability that at least two of the three orders will be recognized correctly : 0.952327936

# %% [markdown]
# **5. Explain 1 real life industry scenario (other than the ones mentioned above) where you can use the concepts learnt in this module of
# Applied Statistics to get data driven business solution.**

# %% [markdown]
# A large MNC Bank want to analyse the data for credit card sale. Company can have sales data from past 10 years and do sampling on that data based on age, gender, income, demographic. Using probility distribution company can predict sales and target customers.
#
# For eg: The probability of customer purchasing a credit card is 0.6 based on age, income and gender and lets say sample is taken as 10 then using binomial distribution we can figure out probability  how many customers actually purchased the product and also no customer purchasing any credit card with n as 10 and p as 0.6 and then array with k = np.arrange(0,10). Using cumilative distribution we can figure out the 0 customers purchasing credit card and exactly 4 customers purchasing credit card.
#
# Using stats and EDA we can analyse further to bring meaningful predictions

# %%
n = 3
p = 0.6
k = np.arange(0,10)

binom1 = binom.cdf(k,n,p)

print("No people purchasing credit card ",binom1[0])
# Out:
# No people purchasing credit card  0.06400000000000002

# %% [markdown]
# # Part B
# *   **Domain**: Sports
# *   **Context**: Company X manages the men's top professional basketball division of the American league system. The dataset contains information
# on all the teams that have participated in all the past tournaments. It has data about how many baskets each team scored, conceded, how many
# times they came within the first 2 positions, how many tournaments they have qualified, their best position in the past, etc.
# DATA DESCRIPTION: Basketball.csv - The data set contains information on all the teams so far participated in all the past tournaments.
# *  **Data Dictionary**:
# 1. Team: Team’s name
# 2. Tournament: Number of played tournaments.
# 3. Score: Team’s score so far.
# 4. PlayedGames: Games played by the team so far.
# 5. WonGames: Games won by the team so far.
# 6. DrawnGames: Games drawn by the team so far.
# 7. LostGames: Games lost by the team so far.
# 8. BasketScored: Basket scored by the team so far.
# 9. BasketGiven: Basket scored against the team so far.
# 10. TournamentChampion: How many times the team was a champion of the tournaments so far.
# 11. Runner-up: How many times the team was a runners-up of the tournaments so far.
# 12. TeamLaunch: Year the team was launched on professional basketball.
# 13. HighestPositionHeld: Highest position held by the team amongst all the tournaments played.
# *   **PROJECT OBJECTIVE**: Company’s management wants to invest on proposals on managing some of the best teams in the league. The analytics
# department has been assigned with a task of creating a report on the performance shown by the teams. Some of the older teams are already in
# contract with competitors. Hence Company X wants to understand which teams they can approach which will be a deal win for them.

# %% [markdown]
# **1. Read the data set, clean the data and prepare final dataset to be used for analysis.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as datetime

# reading the CSV file
basketball = pd.read_csv('DS+-+Part2+-+Basketball.csv')

# check for head
basketball.head()
# Out:
#      Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0  Team 1          86  4385        2762     1647        552       563
# 1  Team 2          86  4262        2762     1581        573       608
# 2  Team 3          80  3442        2614     1241        598       775
# 3  Team 4          82  3386        2664     1187        616       861
# 4  Team 5          86  3368        2762     1209        633       920
#
#   BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 0         5947        3140                 33        23       1929
# 1         5900        3114                 25        25       1929
# 2         4534        3309                 10         8       1929
# 3         4398        3469                  6         6   1931to32
# 4         4631        3700                  8         7       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# ...

# %%
# check of tail
basketball.tail()
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     -           -        -          -         -
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 56           38          66                  -         -    2009-10
# 57           37          57                  -         -    1956-57
# 58           51          85                  -         -    1951~52
# 59           34          65                  -         -    1955-56
# 60            -           -                  -         -    2017~18
#
#     HighestPositionHeld
# 56                   20
# 57                   16
# 58                   16
# ...

# %% [markdown]
# We can see there are some missing data and is marked as "-" and team launch value isnt in one format/incorrect format

# %%
#inspecting data
basketball.shape
# Out:
# (61, 13)

# %% [markdown]
# This means there are 61 rows and 13 columns which means 61 observations and 13 independent values

# %%
# display all column names
basketball.columns
# Out:
# Index(['Team', 'Tournament', 'Score', 'PlayedGames', 'WonGames', 'DrawnGames',
#        'LostGames', 'BasketScored', 'BasketGiven', 'TournamentChampion',
#        'Runner-up', 'TeamLaunch', 'HighestPositionHeld'],
#       dtype='object')

# %%
# display columns datatypes total counts of each column
basketball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     object
#  3   PlayedGames          61 non-null     object
#  4   WonGames             61 non-null     object
#  5   DrawnGames           61 non-null     object
#  6   LostGames            61 non-null     object
#  7   BasketScored         61 non-null     object
#  8   BasketGiven          61 non-null     object
#  9   TournamentChampion   61 non-null     object
#  10  Runner-up            61 non-null     object
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.3+ KB

# %% [markdown]
# From above we can see there are 2 int type columns and 11 object types and that data types of columns are not correct for many columns, its showing as object when it should be int

# %% [markdown]
# Cleaning the data

# %% [markdown]
# Replacing missing maked as "-" with 0

# %%
basketball.replace(to_replace='-',value=0,inplace=True)

#verifying the replacement
basketball.tail()
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     0           0        0          0         0
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 56           38          66                  0         0    2009-10
# 57           37          57                  0         0    1956-57
# 58           51          85                  0         0    1951~52
# 59           34          65                  0         0    1955-56
# 60            0           0                  0         0    2017~18
#
#     HighestPositionHeld
# 56                   20
# 57                   16
# 58                   16
# ...

# %% [markdown]
# we can see that all the "-" values are replaced with 0

# %%
# correcting Team launch data to year only by taking first 4 characters
basketball['TeamLaunch']  = basketball['TeamLaunch'].apply(lambda year: str(year)[:4])

#verifying data
basketball.head()
# Out:
#      Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0  Team 1          86  4385        2762     1647        552       563
# 1  Team 2          86  4262        2762     1581        573       608
# 2  Team 3          80  3442        2614     1241        598       775
# 3  Team 4          82  3386        2664     1187        616       861
# 4  Team 5          86  3368        2762     1209        633       920
#
#   BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 0         5947        3140                 33        23       1929
# 1         5900        3114                 25        25       1929
# 2         4534        3309                 10         8       1929
# 3         4398        3469                  6         6       1931
# 4         4631        3700                  8         7       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# ...

# %%
basketball.tail()
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     0           0        0          0         0
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 56           38          66                  0         0       2009
# 57           37          57                  0         0       1956
# 58           51          85                  0         0       1951
# 59           34          65                  0         0       1955
# 60            0           0                  0         0       2017
#
#     HighestPositionHeld
# 56                   20
# 57                   16
# 58                   16
# ...

# %% [markdown]
# We can see from above head and tail that TeamLaunch is coverted to right year format and missing data "-" is now replaced with 0. We now need to correct the datatype

# %%
#correcting data types
columns = basketball.columns
basketball[columns[1:]] = basketball[columns[1:]].astype('int64')

#checking datatype
basketball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     int64
#  3   PlayedGames          61 non-null     int64
#  4   WonGames             61 non-null     int64
#  5   DrawnGames           61 non-null     int64
#  6   LostGames            61 non-null     int64
#  7   BasketScored         61 non-null     int64
#  8   BasketGiven          61 non-null     int64
#  9   TournamentChampion   61 non-null     int64
#  10  Runner-up            61 non-null     int64
#  11  TeamLaunch           61 non-null     int64
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 6.3+ KB

# %% [markdown]
# Now data is ready for analysis and cleaning is completed

# %% [markdown]
# 2. Perform detailed statistical analysis and EDA using univariate, bi-variate and multivariate EDA techniques to get data driven insights on
# recommending which teams they can approach which will be a deal win for them. Also as a data and statistics expert you have to develop a
# detailed performance report using this data.

# %% [markdown]
# Five Point Summary

# %%
basketball.describe()
# Out:
#        Tournament        Score  PlayedGames     WonGames  DrawnGames  \
# count   61.000000    61.000000    61.000000    61.000000   61.000000
# mean    24.000000   901.426230   796.819672   303.967213  188.934426
# std     26.827225  1134.899121   876.282765   406.991030  201.799477
# min      1.000000     0.000000     0.000000     0.000000    0.000000
# 25%      4.000000    96.000000   114.000000    34.000000   24.000000
# 50%     12.000000   375.000000   423.000000   123.000000   95.000000
# 75%     38.000000  1351.000000  1318.000000   426.000000  330.000000
# max     86.000000  4385.000000  2762.000000  1647.000000  633.000000
#
#          LostGames  BasketScored  BasketGiven  TournamentChampion  Runner-up  \
# count    61.000000     61.000000    61.000000           61.000000  61.000000
# mean    303.754098   1140.344262  1140.229508            1.426230   1.409836
# std     294.708594   1506.740211  1163.710766            5.472535   4.540107
# ...

# %% [markdown]
# From above we can see that mean > median which means that data is positivly scewed

# %%
Mean = basketball['PlayedGames'].mean()
Median = basketball['PlayedGames'].median()
plt.figure(figsize=(10,5))
plt.hist(basketball['PlayedGames'],bins=100,color='b')

plt.axvline(Mean,color='r',label='Mean')
plt.axvline(Median,color='g',label='Median')

plt.xlabel('PlayedGames')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
#Finding IQR
basketball.quantile(0.75)-basketball.quantile(0.25)
# Out:
# <ipython-input-398-7f3647aba6a5>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   basketball.quantile(0.75)-basketball.quantile(0.25)
# Tournament               34.0
# Score                  1255.0
# PlayedGames            1204.0
# WonGames                392.0
# DrawnGames              306.0
# LostGames               501.0
# BasketScored           1489.0
# BasketGiven            1730.0
# TournamentChampion        0.0
# Runner-up                 0.0
# TeamLaunch               43.0
# HighestPositionHeld       7.0
# dtype: float64

# %%
#checking data skew
basketball.skew()
# Out:
# <ipython-input-399-4ac42d8a0754>:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   basketball.skew()
# Tournament             1.217038
# Score                  1.593109
# PlayedGames            1.141978
# WonGames               1.805728
# DrawnGames             1.004159
# LostGames              0.897130
# BasketScored           1.777436
# BasketGiven            0.975859
# TournamentChampion     4.777021
# Runner-up              4.360643
# TeamLaunch             0.672956
# HighestPositionHeld    0.817976
# dtype: float64

# %%
basketball.Score.plot(kind='box',figsize=(5,5))
# Out:
# <Axes: >

# %% [markdown]
# For above we can see score has outliers and mean is near Q1 which means its rightly skewed

# %%
basketball.WonGames.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# For above we can see WonGames has outliers and mean is near Q1 which means its rightly skewed

# %%
#creating copy of original data

basketball2 = basketball.copy()

basketball2.head()
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
#
#    BasketScored  BasketGiven  TournamentChampion  Runner-up  TeamLaunch  \
# 0          5947         3140                  33         23        1929
# 1          5900         3114                  25         25        1929
# 2          4534         3309                  10          8        1929
# 3          4398         3469                   6          6        1931
# 4          4631         3700                   8          7        1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# ...

# %%
#adding winning percentage

winning_perc = (basketball2['WonGames']/basketball2['PlayedGames'])*100
basketball2.insert(loc=7, column='WinPercentage',value=winning_perc)

# %%
basketball2.head()
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
#
#    WinPercentage  BasketScored  BasketGiven  TournamentChampion  Runner-up  \
# 0      59.630702          5947         3140                  33         23
# 1      57.241130          5900         3114                  25         25
# 2      47.475134          4534         3309                  10          8
# 3      44.557057          4398         3469                   6          6
# 4      43.772629          4631         3700                   8          7
#
#    TeamLaunch  HighestPositionHeld
# ...

# %%
#adding winning ratio
winning_ratio = basketball2['WonGames']/basketball2['LostGames']
basketball2.insert(loc=8,column='WinRatio',value=winning_ratio)

# %%
basketball2.head()
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
#
#    WinPercentage  WinRatio  BasketScored  BasketGiven  TournamentChampion  \
# 0      59.630702  2.925400          5947         3140                  33
# 1      57.241130  2.600329          5900         3114                  25
# 2      47.475134  1.601290          4534         3309                  10
# 3      44.557057  1.378630          4398         3469                   6
# 4      43.772629  1.314130          4631         3700                   8
#
#    Runner-up  TeamLaunch  HighestPositionHeld
# ...

# %%
#adding loss percentage
loss_perc = (basketball2['LostGames']/basketball2['PlayedGames'])*100
basketball2.insert(loc=8,column='LossPercentage',value=loss_perc)

# %%
basketball2.head()
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
#
#    WinPercentage  LossPercentage  WinRatio  BasketScored  BasketGiven  \
# 0      59.630702       20.383780  2.925400          5947         3140
# 1      57.241130       22.013034  2.600329          5900         3114
# 2      47.475134       29.648049  1.601290          4534         3309
# 3      44.557057       32.319820  1.378630          4398         3469
# 4      43.772629       33.309196  1.314130          4631         3700
#
#    TournamentChampion  Runner-up  TeamLaunch  HighestPositionHeld
# ...

# %%
#adding teams age
age = datetime.datetime.now().year - basketball2['TeamLaunch']
basketball2.insert(loc=14,column='TeamsAge',value=age)

# %%
basketball2.head()
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
#
#    WinPercentage  LossPercentage  WinRatio  BasketScored  BasketGiven  \
# 0      59.630702       20.383780  2.925400          5947         3140
# 1      57.241130       22.013034  2.600329          5900         3114
# 2      47.475134       29.648049  1.601290          4534         3309
# 3      44.557057       32.319820  1.378630          4398         3469
# 4      43.772629       33.309196  1.314130          4631         3700
#
#    TournamentChampion  Runner-up  TeamsAge  TeamLaunch  HighestPositionHeld
# ...

# %%
#average basket given per game
basket_given_avg = (basketball2['BasketGiven']/basketball2['PlayedGames'])

basketball2.insert(loc=11,column='BasketGivenAverage',value=basket_given_avg)

# %%
basketball2.head()
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
#
#    WinPercentage  LossPercentage  WinRatio  BasketScored  BasketGivenAverage  \
# 0      59.630702       20.383780  2.925400          5947            1.136857
# 1      57.241130       22.013034  2.600329          5900            1.127444
# 2      47.475134       29.648049  1.601290          4534            1.265876
# 3      44.557057       32.319820  1.378630          4398            1.302177
# 4      43.772629       33.309196  1.314130          4631            1.339609
#
# ...

# %%
#average basket scored per game
basket_scored_avg = (basketball2['BasketScored']/basketball2['PlayedGames'])

basketball2.insert(loc=10,column='BasketScoredAverage',value=basket_scored_avg)

# %%
basketball2.head()
# Out:
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
#
#    WinPercentage  LossPercentage  WinRatio  BasketScoredAverage  BasketScored  \
# 0      59.630702       20.383780  2.925400             2.153150          5947
# 1      57.241130       22.013034  2.600329             2.136133          5900
# 2      47.475134       29.648049  1.601290             1.734507          4534
# 3      44.557057       32.319820  1.378630             1.650901          4398
# 4      43.772629       33.309196  1.314130             1.676684          4631
#
# ...

# %%
#average score per game
avg_score = basketball2['Score']/basketball2['PlayedGames']

basketball2.insert(loc=3,column='ScoreAverage',value=avg_score)

# %%
basketball2.head()
# Out:
#      Team  Tournament  Score  ScoreAverage  PlayedGames  WonGames  DrawnGames  \
# 0  Team 1          86   4385      1.587618         2762      1647         552
# 1  Team 2          86   4262      1.543085         2762      1581         573
# 2  Team 3          80   3442      1.316756         2614      1241         598
# 3  Team 4          82   3386      1.271021         2664      1187         616
# 4  Team 5          86   3368      1.219406         2762      1209         633
#
#    LostGames  WinPercentage  LossPercentage  WinRatio  BasketScoredAverage  \
# 0        563      59.630702       20.383780  2.925400             2.153150
# 1        608      57.241130       22.013034  2.600329             2.136133
# 2        775      47.475134       29.648049  1.601290             1.734507
# 3        861      44.557057       32.319820  1.378630             1.650901
# 4        920      43.772629       33.309196  1.314130             1.676684
#
# ...

# %%
basketball2.tail()
# Out:
#        Team  Tournament  Score  ScoreAverage  PlayedGames  WonGames  \
# 56  Team 57           1     34      0.894737           38         8
# 57  Team 58           1     22      0.733333           30         7
# 58  Team 59           1     19      0.633333           30         7
# 59  Team 60           1     14      0.466667           30         5
# 60  Team 61           1      0           NaN            0         0
#
#     DrawnGames  LostGames  WinPercentage  LossPercentage  WinRatio  \
# 56          10         20      21.052632       52.631579  0.400000
# 57           8         15      23.333333       50.000000  0.466667
# 58           5         18      23.333333       60.000000  0.388889
# 59           4         21      16.666667       70.000000  0.238095
# 60           0          0            NaN             NaN       NaN
#
#     BasketScoredAverage  BasketScored  BasketGivenAverage  BasketGiven  \
# 56             1.000000            38            1.736842           66
# ...

# %% [markdown]
# There are some new columns with NaN value, will replace them with 0

# %%
basketball2['ScoreAverage'].fillna(0,inplace=True)
basketball2['WinPercentage'].fillna(0,inplace=True)
basketball2['LossPercentage'].fillna(0,inplace=True)
basketball2['BasketScoredAverage'].fillna(0,inplace=True)
basketball2['BasketGivenAverage'].fillna(0,inplace=True)
basketball2['WinRatio'].fillna(0,inplace=True)

# %%
basketball2.tail()
# Out:
#        Team  Tournament  Score  ScoreAverage  PlayedGames  WonGames  \
# 56  Team 57           1     34      0.894737           38         8
# 57  Team 58           1     22      0.733333           30         7
# 58  Team 59           1     19      0.633333           30         7
# 59  Team 60           1     14      0.466667           30         5
# 60  Team 61           1      0      0.000000            0         0
#
#     DrawnGames  LostGames  WinPercentage  LossPercentage  WinRatio  \
# 56          10         20      21.052632       52.631579  0.400000
# 57           8         15      23.333333       50.000000  0.466667
# 58           5         18      23.333333       60.000000  0.388889
# 59           4         21      16.666667       70.000000  0.238095
# 60           0          0       0.000000        0.000000  0.000000
#
#     BasketScoredAverage  BasketScored  BasketGivenAverage  BasketGiven  \
# 56             1.000000            38            1.736842           66
# ...

# %%
basketball2.describe()
# Out:
#        Tournament        Score  ScoreAverage  PlayedGames     WonGames  \
# count   61.000000    61.000000     61.000000    61.000000    61.000000
# mean    24.000000   901.426230      0.962493   796.819672   303.967213
# std     26.827225  1134.899121      0.247923   876.282765   406.991030
# min      1.000000     0.000000      0.000000     0.000000     0.000000
# 25%      4.000000    96.000000      0.823529   114.000000    34.000000
# 50%     12.000000   375.000000      0.984899   423.000000   123.000000
# 75%     38.000000  1351.000000      1.063214  1318.000000   426.000000
# max     86.000000  4385.000000      1.587618  2762.000000  1647.000000
#
#        DrawnGames    LostGames  WinPercentage  LossPercentage   WinRatio  \
# count   61.000000    61.000000      61.000000       61.000000  61.000000
# mean   188.934426   303.754098      30.850613       44.254376   0.755031
# std    201.799477   294.708594       8.742574       10.128346   0.457434
# ...

# %% [markdown]
# Average teams age is 65 years
# Yougest team is 7 years old and max teams age is 95 years

# %%
basketball2.TeamsAge.mode()
# Out:
# 0    95
# Name: TeamsAge, dtype: int64

# %% [markdown]
# Most Teams are 95 years old

# %%
df = basketball2[['Team','WinRatio']]
df.sort_values('WinRatio', ascending=False).head(1)
# Out:
#      Team  WinRatio
# 0  Team 1    2.9254

# %% [markdown]
# Team 1 is best performing team

# %%
sns.displot(basketball2['Score'],kde=True)

# %% [markdown]
# This tells us that there are more team scoreing between 0 to 1800 and less team scoring above 2000

# %%
df = basketball2.sort_values(['TournamentChampion']).tail(10)
df.plot(x='Team',y='TournamentChampion',kind='bar',figsize=(10,5))
plt.title('Top 10 Team Won tournament')
plt.xlabel('Team Name')
plt.ylabel('Count as Champion')
plt.show()

# %% [markdown]
# Team 1 has highest winning touranments

# %%
plt.figure(figsize=(15,5))
plt.title('Top 15 Team by winning match %')
df = basketball2.sort_values(['WonGames']).tail(15)
ax = sns.barplot(x='Team', y='WinPercentage', data=df, palette='muted');  # barplot
ax.set_xlabel("Team Name");
ax.set_ylabel("Game won %");
# Out:
# <ipython-input-425-d9ea5f5a179d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Team', y='WinPercentage', data=df, palette='muted');  # barplot

# %% [markdown]
# From above we can see that Team 1 has more winning percentage

# %%
#finding wining loss and draw
df = basketball2.loc[:, ['Team', 'WonGames','LostGames']]
df = df.sort_values(['WonGames']).tail(15)
# Melt the DataFrame to convert the data from wide to long format
melted_df = df.melt(id_vars='Team', var_name='Result', value_name='Count')

plt.figure(figsize=(20,5))
plt.title('Top 15 Team by winning match')

ax = sns.barplot(x='Team', y='Count', hue='Result', data=melted_df)
ax.set_xlabel("Team Name");
ax.set_ylabel("Game won %");

plt.show()

# %%
sns.lineplot(x='WinPercentage',y='TournamentChampion',data=basketball2)
# Out:
# <Axes: xlabel='WinPercentage', ylabel='TournamentChampion'>

# %% [markdown]
# Above chart we can see Tournament Champtionships and win are positivly associated

# %%
basketball2.corr()
# Out:
# <ipython-input-428-69137b25b880>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   basketball2.corr()
#                      Tournament     Score  ScoreAverage  PlayedGames  \
# Tournament             1.000000  0.981441      0.617064     0.998677
# Score                  0.981441  1.000000      0.677342     0.979824
# ScoreAverage           0.617064  0.677342      1.000000     0.629385
# PlayedGames            0.998677  0.979824      0.629385     1.000000
# WonGames               0.971954  0.997240      0.663134     0.967641
# DrawnGames             0.989387  0.958452      0.616582     0.994053
# LostGames              0.949863  0.880040      0.533301     0.956503
# WinPercentage          0.774695  0.822660      0.859082     0.771606
# LossPercentage        -0.558782 -0.603495     -0.348178    -0.559847
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(basketball2.corr(), annot=True,linewidths='.5',fmt='.1f',cmap='Set2')
plt.show()
# Out:
# <ipython-input-429-ea4980162def>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(basketball2.corr(), annot=True,linewidths='.5',fmt='.1f',cmap='Set2')

# %% [markdown]
# 3. Please include any improvements or suggestions to the association management on quality, quantity, variety, velocity, veracity etc. on the
# data points collected by the association to perform a better data analysis in future. At-least 1 suggestion for each point

# %% [markdown]
# 1.   Quality : Quality of data realy speeds up the analysis, the value of data increases depedning upon the insights that can be drawn from it, like few data where we had missing values with "-" and format of year not correct. New features like age of team, winning percentage, ratio can give good insight of the team like best and worst performer
#
# 2.   Quantity : Quantity of data enables organizations to extract meaningful insights, make informed decisions. By adding more columns like matches played against which teams, Tournaments won year can help in bringing more insights
#
# 3.   Variety : Variety allows organizations to unlock insights that would be challenging or impossible to achieve with a narrow, single-source focus. Data like region the team belongs to, team manager, number of disqulifications, team players changing, narrow wins can provide more comprehensive views
#
# 4.   Velocity: Velocity provides ability to provide timely insights, support real-time decision-making, and enable organizations to adapt swiftly to dynamic environments. More realtime data like In-performance analytics, Fan engagement, Game strategies
#
# 5.   Veracity: Varicity is about whether data can be relied upon for making informed decision. Like Launch Year in incorrect format, "-" for missing values, data types int columns as object should be ensured to correct, consistent and accurate

# %% [markdown]
# # Part C
# *   **DOMAIN**: Startup ecosystem
# *   **CONTEXT**: Company X is a EU online publisher focusing on the startups industry. The company specifically reports on the business related to
# technology news, analysis of emerging trends and profiling of new tech businesses and products. Their event i.e. Startup Battlefield is the world’s
# pre-eminent startup competition. Startup Battlefield features 15-30 top early stage startups pitching top judges in front of a vast live audience,
# present in person and online.
# *   **DATA DESCRIPTION**: CompanyX_EU.csv - Each row in the dataset is a Start-up company and the columns describe the company.
# *   **DATA DICTIONARY**:
# 1. Startup: Name of the company
# 2. Product: Actual product
# 3. Funding: Funds raised by the company in USD
# 4. Event: The event the company participated in
# 5. Result: Described by Contestant, Finalist, Audience choice, Winner or Runner up
# 6. OperatingState: Current status of the company, Operating ,Closed, Acquired or IPO

# %% [markdown]
# 1. Read the CSV file

# %%
# reading file
company = pd.read_csv('DS+-+Part3+-+CompanyX_EU.csv')

# %% [markdown]
# 2. Data Exploration:

# %%
company.head()
# Out:
#            Startup             Product Funding             Event  \
# 0           2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1             3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2      3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3       3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4  42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
#
#             Result OperatingState
# 0       Contestant      Operating
# 1       Contestant         Closed
# 2       Contestant      Operating
# 3  Audience choice      Operating
# 4       Contestant      Operating

# %%
company.shape
# Out:
# (662, 6)

# %% [markdown]
# A. Check the datatypes of each attribute

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Startup         662 non-null    object
#  1   Product         656 non-null    object
#  2   Funding         448 non-null    object
#  3   Event           662 non-null    object
#  4   Result          662 non-null    object
#  5   OperatingState  662 non-null    object
# dtypes: object(6)
# memory usage: 31.2+ KB

# %%
company.dtypes
# Out:
# Startup           object
# Product           object
# Funding           object
# Event             object
# Result            object
# OperatingState    object
# dtype: object

# %% [markdown]
# B. Check for null values in the attributes:

# %%
pd.DataFrame( company.isnull().sum(), columns= ['Number of Null values'])
# Out:
#                 Number of Null values
# Startup                             0
# Product                             6
# Funding                           214
# Event                               0
# Result                              0
# OperatingState                      0

# %% [markdown]
# 3. Data preprocessing & visualisation

# %% [markdown]
# A. Drop the null values.

# %%
company1 = company.dropna().copy(deep=True)
pd.DataFrame( company1.isnull().sum(), columns= ['Number of Null values'])
# Out:
#                 Number of Null values
# Startup                             0
# Product                             0
# Funding                             0
# Event                               0
# Result                              0
# OperatingState                      0

# %% [markdown]
# B. Convert the ‘Funding’ features to a numerical value.

# %%
company1.loc[:,'Funds_in_million'] = company1['Funding'].apply(lambda x: float(x[1:-1])/1000 if x[-1] == 'K' else (float(x[1:-1])*1000 if x[-1] == 'B' else float(x[1:-1])))

company1.dtypes
# Out:
# Startup              object
# Product              object
# Funding              object
# Event                object
# Result               object
# OperatingState       object
# Funds_in_million    float64
# dtype: object

# %% [markdown]
# C. Plot box plot for funds in million

# %%
sns.boxplot(company1.Funds_in_million)
plt.title("Boxplot : Funds_in_million")
plt.ylim(-10,50)
# Out:
# (-10.0, 50.0)

# %% [markdown]
# D. Check the number of outliers greater than the upper fence

# %%
Q3 = company1['Funds_in_million'].quantile(0.75)
Q1 = company1['Funds_in_million'].quantile(0.25)
IQR = Q3 - Q1
upper_fence = Q3 + 1.5 * IQR

# number of outliers greater than the upper fence
num_outliers = len(company1[company1['Funds_in_million'] > upper_fence])

print("Number of outliers greater than upper fence:", num_outliers)
# Out:
# Number of outliers greater than upper fence: 60

# %% [markdown]
# E. Check frequency of the OperatingState features classes.

# %%
company1['OperatingState'].unique()
# Out:
# array(['Closed', 'Operating', 'Acquired', 'Ipo'], dtype=object)

# %%
company1['OperatingState'].value_counts()
# Out:
# Operating    319
# Acquired      66
# Closed        57
# Ipo            4
# Name: OperatingState, dtype: int64

# %% [markdown]
# 4. Statistical Analysis:

# %% [markdown]
# A. Is there any significant difference between Funds raised by companies that are still operating vs companies that closed down?

# %%
from scipy.stats import ttest_ind

# assume significance level
alpha = 0.05
operating_funds = company1[company1['OperatingState'] == 'Operating']['Funds_in_million']
closed_funds = company1[company1['OperatingState'] == 'Closed']['Funds_in_million']

t_statistic, p_value = ttest_ind(operating_funds, closed_funds, equal_var=True)

print('P-Value:', p_value)

if p_value < alpha:
  print("we reject the null hypothesis and conclude that there is a significant difference between the funds raised by startups operating and closed.")
else:
  print("we accpet the null hypothesis and conclude that there is no significant difference in the funds raised by  startups that are operating versus closed")
# Out:
# P-Value: 0.25572701885629406
# we accpet the null hypothesis and conclude that there is no significant difference in the funds raised by  startups that are operating versus closed

# %% [markdown]
# **B. Write the null hypothesis and alternative hypothesis.**
#
# Ho : Null Hypothesis
#
# There is no difference between the two means of funds raised by Operating and Closed Companies.
#
# Ha : Alternate Hypothesis
#
# There is difference between the means of the funds raised by Operating and Closed Companies.

# %% [markdown]
# C. Test for significance and conclusion

# %%
from scipy.stats import ttest_ind

# assume significance level
alpha = 0.05
operating_funds = company1[company1['OperatingState'] == 'Operating']['Funds_in_million']
closed_funds = company1[company1['OperatingState'] == 'Closed']['Funds_in_million']

t_statistic, p_value = ttest_ind(operating_funds, closed_funds, equal_var=True)

print('P-Value:', p_value)

if p_value < alpha:
  print("we reject the null hypothesis and conclude that there is a significant difference between the funds raised by startups operating and closed.")
else:
  print("we accpet the null hypothesis and conclude that there is no significant difference in the funds raised by  startups that are operating versus closed")
# Out:
# P-Value: 0.25572701885629406
# we accpet the null hypothesis and conclude that there is no significant difference in the funds raised by  startups that are operating versus closed

# %% [markdown]
# D. Make a copy of the original data frame.

# %%
datacopy = company.copy(deep=True)
datacopy.head()
# Out:
#            Startup             Product Funding             Event  \
# 0           2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1             3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2      3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3       3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4  42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
#
#             Result OperatingState
# 0       Contestant      Operating
# 1       Contestant         Closed
# 2       Contestant      Operating
# 3  Audience choice      Operating
# 4       Contestant      Operating

# %% [markdown]
# E. Check frequency distribution of Result variables.

# %%
datacopy['Result'].value_counts()
# Out:
# Contestant         488
# Finalist            84
# Audience choice     41
# Winner              26
# Runner up           23
# Name: Result, dtype: int64

# %% [markdown]
# F. Calculate percentage of winners that are still operating and percentage of contestants that are still operating

# %%
data_filtered = datacopy[datacopy['Result'].isin(['Winner', 'Contestant'])]

# calculate percentage of winners that are still operating
w_operating = data_filtered[data_filtered['Result'] == 'Winner']['OperatingState'].value_counts(normalize=True)['Operating'] * 100

# calculate percentage of contestants that are still operating
c_operating = data_filtered[data_filtered['Result'] == 'Contestant']['OperatingState'].value_counts(normalize=True)['Operating'] * 100

print("winners still operating: ",w_operating.round(2),"%")
print("contestants still operating:",c_operating.round(2),"%")
# Out:
# winners still operating:  73.08 %
# contestants still operating: 68.03 %

# %% [markdown]
# G. Write your hypothesis comparing the proportion of companies that are operating between winners and contestants

# %% [markdown]
# Null hypothesis No significant difference in the proportion of startups that are operating between winners and contestants.
#
# Alternative hypothesis The proportion of startups that are operating is significantly different between winners and contestants.

# %% [markdown]
# H. Test for significance and conclusion

# %%
# Test for significance and conclusion
from scipy.stats import chi2_contingency
# Create a contingency table
contingency_table = pd.crosstab(data_filtered['Result'], data_filtered['OperatingState'])

# Print the contingency table
print(contingency_table)

# Perform chi-squared test
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(p)

# Assume significance value
alpha = 0.05

if p < alpha:
    print("Reject null hypothesis. There is a significant difference in the proportion of companies that are operating between winners and contestants.")
else:
    print("Fail to reject null hypothesis. There is no significant difference in the proportion of companies that are operating between winners and contestants.")
# Out:
# OperatingState  Acquired  Closed  Ipo  Operating
# Result
# Contestant            62      90    4        332
# Winner                 7       0    0         19
# 0.03181839969026595
# Reject null hypothesis. There is a significant difference in the proportion of companies that are operating between winners and contestants.

# %% [markdown]
# I. Select only the Event that has ‘disrupt’ keyword from 2013 onwards.

# %%
disrupt_events = datacopy[datacopy['Event'].str.contains('disrupt', case=False)]

disrupt_events_gt_2013 = disrupt_events[disrupt_events['Event'].str[-4:].astype(int) >= 2013]

disrupt_events_gt_2013
# Out:
#              Startup             Product  Funding                Event  \
# 0             2600Hz          2600hz.com      NaN      Disrupt SF 2013
# 1               3DLT            3dlt.com    $630K     Disrupt NYC 2013
# 2        3DPrinterOS     3dprinteros.com      NaN      Disrupt SF 2016
# 3         3Dprintler      3dprintler.com      $1M      Disrupt NY 2016
# 4    42 Technologies  42technologies.com      NaN     Disrupt NYC 2013
# ..               ...                 ...      ...                  ...
# 646       YayPay Inc          yaypay.com    $900K  Disrupt London 2015
# 648           YOOBIC          yoobic.com      NaN  Disrupt London 2015
# 653             ZAP!      zapreklam.com/      NaN      Disrupt EU 2014
# 656         Zenefits        zenefits.com  $583.6M     Disrupt NYC 2013
# 660             Zula         zulaapp.com    $3.4M      Disrupt SF 2013
#
#               Result OperatingState
# 0         Contestant      Operating
# 1         Contestant         Closed
# ...
